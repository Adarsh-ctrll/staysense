# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub
import os
# Download latest version
path = kagglehub.dataset_download("dgomonov/new-york-city-airbnb-open-data")

print("Path to dataset files:", path)
df=pd.read_csv(os.path.join(path,"AB_NYC_2019.csv"))
df
# Out:
# Path to dataset files: C:\Users\ASUS\.cache\kagglehub\datasets\dgomonov\new-york-city-airbnb-open-data\versions\3
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
# EDA

missing=df.isnull().sum()
missing[missing>0]
# Out:
# name                    16
# host_name               21
# last_review          10052
# reviews_per_month    10052
# dtype: int64

# %%
df['room_type'].unique()
# Out:
# <StringArray>
# ['Private room', 'Entire home/apt', 'Shared room']
# Length: 3, dtype: str

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
#biasness class imbalanace bcz two are high count one is low
sns.countplot(x='room_type',data=df)
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
#the classes are imbalamnced =>shared room is a small minority and rest are in large occurances
numerical_cols = ["price", "minimum_nights", "number_of_reviews",
                 "reviews_per_month", "calculated_host_listings_count",
                 "availability_365"]

df[numerical_cols].hist(bins=30,figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'minimum_nights'}>],
#        [<Axes: title={'center': 'number_of_reviews'}>,
#         <Axes: title={'center': 'reviews_per_month'}>],
#        [<Axes: title={'center': 'calculated_host_listings_count'}>,
#         <Axes: title={'center': 'availability_365'}>]], dtype=object)

# %%
sns.countplot(data=df,x='neighbourhood_group')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
#bivriate analystis

sns.boxplot(x='room_type',y='price',data=df)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
corr=df[numerical_cols+['latitude','longitude']].corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='longitude',y='latitude',data=df,hue='room_type')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
#data cleaning feature scaling
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df['name'].nunique()
# Out:
# 47905

# %%
df_clean=df.drop(columns=['id','name','host_id','host_name','last_review'])

# %%
df_clean
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 0                Brooklyn          Kensington  40.64749  -73.97237
# 1               Manhattan             Midtown  40.75362  -73.98377
# 2               Manhattan              Harlem  40.80902  -73.94190
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# ...                   ...                 ...       ...        ...
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48892           Manhattan              Harlem  40.81475  -73.94867
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room    149               1                  9
# ...

# %%
df_clean['reviews_per_month']=df_clean['reviews_per_month'].fillna(0)

# %%
df_clean
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 0                Brooklyn          Kensington  40.64749  -73.97237
# 1               Manhattan             Midtown  40.75362  -73.98377
# 2               Manhattan              Harlem  40.80902  -73.94190
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# ...                   ...                 ...       ...        ...
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48892           Manhattan              Harlem  40.81475  -73.94867
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room    149               1                  9
# ...

# %%
#cap extreme outliers instead a deleteing rows
price_cap=df_clean['price'].quantile(0.99)
nights_cap=df_clean['minimum_nights'].quantile(0.99)

df_clean['price'] = df_clean['price'].clip(upper=price_cap)

df_clean['minimum_nights'] = df_clean['minimum_nights'].clip(
    upper=nights_cap
)
df_clean
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 0                Brooklyn          Kensington  40.64749  -73.97237
# 1               Manhattan             Midtown  40.75362  -73.98377
# 2               Manhattan              Harlem  40.80902  -73.94190
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# ...                   ...                 ...       ...        ...
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48892           Manhattan              Harlem  40.81475  -73.94867
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room    149               1                  9
# ...

# %%
#bivriate analystis

sns.boxplot(x='room_type',y='price',data=df_clean)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
X=df_clean.drop(columns=['room_type'])
y = df_clean['room_type']

# %%
#stratisfy
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42,stratify=y)

# %%
#startisfy insures that when there is spitting or sampling then all group or class maintains their original proportional

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\AirbnbRoomPredictor\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder,PowerTransformer
from sklearn.compose import ColumnTransformer

# %%
#columntranformer +pipeline


numerical_cols = ["latitude","longitude","price", "minimum_nights", "number_of_reviews",
                 "reviews_per_month", "calculated_host_listings_count",
                 "availability_365"]

categorical_cols = ['neighbourhood_group', 'neighbourhood']

#pipeline for numerica columns
#1. Pipeline -> for Numeric Columns
numeric_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy="median")),
    ('skewness', PowerTransformer(method='yeo-johnson')),
    ('scale', StandardScaler())
])


#2. Pipeline -> for Categorical Columns
categorical_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy="most_frequent")),
    ('encode', OneHotEncoder(handle_unknown='ignore'))
]) 

preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, numerical_cols),
    ('cat', categorical_pipeline, categorical_cols)
])

# %%
df_clean
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 0                Brooklyn          Kensington  40.64749  -73.97237
# 1               Manhattan             Midtown  40.75362  -73.98377
# 2               Manhattan              Harlem  40.80902  -73.94190
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# ...                   ...                 ...       ...        ...
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48892           Manhattan              Harlem  40.81475  -73.94867
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room    149               1                  9
# ...

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('skewness',
#                                                   PowerTransformer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['latitude', 'longitude', 'price',
#                                   'minimum_nights', 'number_of_reviews',
#                                   'reviews_per_month',
#                                   'calculated_host_listings_count',
#                                   'availability_365']),
#                                 ('cat',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encode',
# ...

# %%
df_clean[numerical_cols].skew()
# Out:
# latitude                          0.237167
# longitude                         1.284210
# price                             2.776321
# minimum_nights                    2.360347
# number_of_reviews                 3.690635
# reviews_per_month                 3.300723
# calculated_host_listings_count    7.933174
# availability_365                  0.763408
# dtype: float64

# %%
# # #multiple algorithm in this class imbalance
# # #SMOTE FOR CLASS IMBALANCE=>SYNTHETIC MINORITY OVERSAMPLING technique

# # disavdante=>1)high chances of overfitting
# # 2)data leakage
# # 3)
# in place of smote we use class weight

# %%
df_clean['room_type'].unique()
# Out:
# <StringArray>
# ['Private room', 'Entire home/apt', 'Shared room']
# Length: 3, dtype: str

# %%
import warnings
warnings.filterwarnings('ignore')


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble  import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

# %%
# class_weight="Balanced" tells the model to pay more attention to the minority class
# or rare class (Shared Room)
# but the problem is GradintBossting doesnt support class weight so we left it as it is.

models = {
    "Logistic Regression" : LogisticRegression(class_weight="balanced",random_state=42),
    "Decision Tree"       : DecisionTreeClassifier(class_weight="balanced",random_state=42),
    "Random Forest"       : RandomForestClassifier(class_weight="balanced", random_state=42),
    "Gradient Boosting"   : GradientBoostingClassifier(random_state=42),
}

for name,model in models.items():
    pipe=Pipeline(steps=[("preprocessor",preprocessor),("classifier",model)])
#accuracy alone can be misleading on imbaklance classes so we uses macro f1 both planbe accuracy and macro f2 score which treats every class equally
    accuracy = cross_val_score(pipe, X_train, y_train,cv=3,scoring="accuracy")
    macrof1 = cross_val_score(pipe, X_train, y_train,cv=3,scoring="f1_macro")
    print(f"{name} -> Accuracy: {accuracy.mean():.3f} , F1: {macrof1.mean():.3f}")
# Out:
# Logistic Regression -> Accuracy: 0.727 , F1: 0.575
# Decision Tree -> Accuracy: 0.783 , F1: 0.651
# Random Forest -> Accuracy: 0.850 , F1: 0.731
# Gradient Boosting -> Accuracy: 0.848 , F1: 0.705

# %%
from sklearn.model_selection import RandomizedSearchCV
#hyper parameter tuning
best_pipeline=Pipeline(steps=[
    ("preprocessor",preprocessor),
    ("classifier",RandomForestClassifier(class_weight="balanced"))
])

param_distribution = {
    "classifier__n_estimators": [100, 150, 200, 300],
    "classifier__max_depth": [8, 12, 15, 20, None],
    "classifier__min_samples_split": [2, 5, 10],
}

search=RandomizedSearchCV(
    estimator=best_pipeline,
    param_distributions=param_distribution,
    n_iter=10,
    cv=3,
    scoring="f1_macro",
    random_state=42
    )

search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('skewness',
#                                                                                                 PowerTransformer()),
#                                                                                                ('scale',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
# ...

# %%
print("Best Parameter",search.best_params_)
print("Best vd macro f1",search.best_score_)
# Out:
# Best Parameter {'classifier__n_estimators': 100, 'classifier__min_samples_split': 2, 'classifier__max_depth': None}
# Best vd macro f1 0.7293924723182691

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,f1_score
best_pipeline = search.best_estimator_

y_pred = best_pipeline.predict(X_test)

print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred, average="macro")}")
# Out:
# Accuracy Score: 0.8523177987109569
# F1 Score: 0.7348915275931301

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.87      0.87      0.87      8385
#    Private room       0.83      0.86      0.84      7368
#     Shared room       0.81      0.35      0.49       383
#
#        accuracy                           0.85     16136
#       macro avg       0.84      0.69      0.73     16136
#    weighted avg       0.85      0.85      0.85     16136

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[7295 1086    4]
#  [1017 6324   27]
#  [  33  216  134]]

# %%
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

smote_pipeline = ImbPipeline(steps=[
    ("preprocessor", preprocessor),
    ("smote", SMOTE(random_state=42)),
    ("classifier", RandomForestClassifier(
        random_state=42
    ))
])

smote_pipeline.fit(X_train, y_train)

y_pred_smote = smote_pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

print("===== CURRENT MODEL =====")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Macro F1:", f1_score(y_test, y_pred, average="macro"))

print("\n===== SMOTE MODEL =====")
print("Accuracy:", accuracy_score(y_test, y_pred_smote))
print("Macro F1:", f1_score(y_test, y_pred_smote, average="macro"))
# Out:
# ===== CURRENT MODEL =====
# Accuracy: 0.8523177987109569
# Macro F1: 0.7348915275931301
#
# ===== SMOTE MODEL =====
# Accuracy: 0.8515121467526029
# Macro F1: 0.7322031354694228

# %%
from sklearn.metrics import classification_report

print("===== CURRENT MODEL =====")
print(classification_report(y_test, y_pred))

print("===== SMOTE MODEL =====")
print(classification_report(y_test, y_pred_smote))
# Out:
# ===== CURRENT MODEL =====
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.87      0.87      0.87      8385
#    Private room       0.83      0.86      0.84      7368
#     Shared room       0.81      0.35      0.49       383
#
#        accuracy                           0.85     16136
#       macro avg       0.84      0.69      0.73     16136
#    weighted avg       0.85      0.85      0.85     16136
#
# ===== SMOTE MODEL =====
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.87      0.88      0.87      8385
#    Private room       0.84      0.85      0.84      7368
#     Shared room       0.67      0.38      0.48       383
#
#        accuracy                           0.85     16136
#       macro avg       0.79      0.70      0.73     16136
#    weighted avg       0.85      0.85      0.85     16136

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=["Entire home/apt", "Private room", "Shared room"],
    yticklabels=["Entire home/apt", "Private room", "Shared room"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
#saving the model

import joblib
joblib.dump(best_pipeline,"model_pipeline.pkl")
# Out:
# ['model_pipeline.pkl']

# %%
test_row = pd.DataFrame([{
    "latitude": -90,
    "longitude": -180,
    "price": 1,
    "minimum_nights": 1,
    "number_of_reviews": 0,
    "reviews_per_month": 0,
    "calculated_host_listings_count": 0,
    "availability_365": 365,
    "neighbourhood_group": "string",
    "neighbourhood": "string"
}])

print(test_row)
print(model.predict(test_row))
# Out:
#    latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0       -90       -180      1               1                  0
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0                               0               365
#
#   neighbourhood_group neighbourhood
# 0              string        string
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 15
#      11     "neighbourhood": "string"
#      12 }])
#      13
#      14 print(test_row)
# ---> 15 print(model.predict(test_row))
#
# File c:\AirbnbRoomPredictor\.venv\Lib\site-packages\sklearn\ensemble\_gb.py:1645, in GradientBoostingClassifier.predict(self, X)
#    1630 def predict(self, X):
#    1631     """Predict class for X.
#    1632
#    1633     Parameters
#    (...)   1643         The predicted values.
#    1644     """
# ...

# %%
print(type(model))
# Out:
# <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>

# %%
print(model)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
print("Current model variable:")
print(model)

print("\nBest pipeline:")
print(best_pipeline.named_steps["classifier"])

loaded_model = joblib.load("model_pipeline.pkl")

print("\nSaved pipeline:")
print(loaded_model.named_steps["classifier"])
# Out:
# Current model variable:
# GradientBoostingClassifier(random_state=42)
#
# Best pipeline:
# RandomForestClassifier(class_weight='balanced')
#
# Saved pipeline:
# RandomForestClassifier(class_weight='balanced')
